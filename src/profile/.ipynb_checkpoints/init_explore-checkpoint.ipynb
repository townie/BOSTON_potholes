# %% [markdown]
# # City of Boston 311 Data Exploration
#
# Digging into what data is on 311, Service RequestsCity Services
#
# https://data.cityofboston.gov/City-Services/311-Service-Requests/awu8-dc52

# %%
# Initialize Python Modules 
import pandas as pd
import pandas_profiling as pdp
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Load Data
#
# https://data.cityofboston.gov/City-Services/311-Service-Requests/awu8-dc52

# %%
df=pd.read_csv("../../data/311__Service_Requests.csv", parse_dates=True, encoding='UTF-8', infer_datetime_format=True)

# %%
df.head()
# Out:
#    CASE_ENQUIRY_ID                 OPEN_DT               TARGET_DT  \
# 0     101000493034  10/16/2012 02:45:25 PM  10/18/2012 02:45:24 PM
# 1     101000362571  12/09/2011 04:04:25 PM                     NaN
# 2     101000301154  07/13/2011 11:40:05 AM  07/15/2011 11:40:05 AM
# 3     101000339191  10/06/2011 02:59:01 PM  10/13/2011 02:59:01 PM
# 4     101000409680  04/18/2012 11:39:15 AM  10/15/2012 11:39:15 AM
#
#                 CLOSED_DT OnTime_Status CASE_STATUS CLOSURE_REASON  \
# 0  10/17/2012 07:36:59 AM        ONTIME      Closed  Case Resolved
# 1  12/19/2011 11:50:23 PM        ONTIME      Closed            NaN
# 2  02/09/2012 04:16:40 PM       OVERDUE      Closed            NaN
# 3  10/12/2011 08:41:41 AM        ONTIME      Closed  Case Resolved
# 4  04/19/2012 09:23:17 AM        ONTIME      Closed  Case Resolved
#
#                     CASE_TITLE                  SUBJECT               REASON  \
# 0              Sticker Request  Public Works Department            Recycling
# 1  Schedule a Bulk Item Pickup  Public Works Department           Sanitation
# 2            Work w/out Permit    Inspectional Services             Building
# 3        Contractor Complaints  Public Works Department  Highway Maintenance
# 4    Upgrade Existing Lighting  Public Works Department        Street Lights
#
#          ...        precinct land_usage LOCATION_STREET_NAME LOCATION_ZIPCODE  \
# 0        ...            1602        NaN           36 Park St           2122.0
# 1        ...            2210        NaN         89 Turner St           2135.0
# 2        ...            1906        NaN        626 Centre St           2130.0
# 3        ...            2213        NaN      50-52 Burton St           2135.0
# 4        ...            0303        NaN       204 Hanover St           2113.0
#
#   Property_Type Property_ID  LATITUDE LONGITUDE              Source  \
# 0           NaN         NaN   42.3011  -71.0543        Self Service
# 1           NaN         NaN   42.3523  -71.1618        Self Service
# 2           NaN         NaN   42.3139  -71.1138    Constituent Call
# 3           NaN         NaN   42.3550  -71.1721    Constituent Call
# 4           NaN         NaN   42.3628  -71.0557  Maximo Integration
#
#   Geocoded_Location
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 33 columns]

# %%
# Show all columns on intial DF
df.columns
# Out:
# Index(['CASE_ENQUIRY_ID', 'OPEN_DT', 'TARGET_DT', 'CLOSED_DT', 'OnTime_Status',
#        'CASE_STATUS', 'CLOSURE_REASON', 'CASE_TITLE', 'SUBJECT', 'REASON',
#        'TYPE', 'QUEUE', 'Department', 'SubmittedPhoto', 'ClosedPhoto',
#        'Location', 'fire_district', 'pwd_district', 'city_council_district',
#        'police_district', 'neighborhood', 'neighborhood_services_district',
#        'ward', 'precinct', 'land_usage', 'LOCATION_STREET_NAME',
#        'LOCATION_ZIPCODE', 'Property_Type', 'Property_ID', 'LATITUDE',
#        'LONGITUDE', 'Source', 'Geocoded_Location'],
#       dtype='object')

# %%
# df.describe()

# %%
# Heavy weight profiling. 
# TODO: Find HUGE columns
# noisey_cols = ['LATITUDE', 'OPEN_DT', 'TARGET_DT','CLOSED_DT', 'CASE_ENQUIRY_ID', 'Location', 'LOCATION_STREET_NAME', 'Property_ID', 'LATITUDE','LONGITUDE', 'LOCATION_ZIPCODE', ]
# pdp.ProfileReport(df[df.columns.difference(noisey_cols)])
important_cols = ['OnTime_Status',
       'CASE_STATUS', 'CLOSURE_REASON', 'CASE_TITLE', 'SUBJECT', 'REASON',
       'TYPE', 'QUEUE', 'Department', 'SubmittedPhoto', 'ClosedPhoto'
       , 'fire_district', 'pwd_district', 'city_council_district',
       'police_district', 'neighborhood', 'neighborhood_services_district',
       'ward', 'precinct', 'land_usage', 'Property_Type', 'Source', 'Geocoded_Location']
# profile = pdp.ProfileReport(df[important_cols])

# %%
# profile.to_file(outputfile="full_profile.html")
# profile

# %%
potdf = df.loc[df['TYPE'].str.contains('Pot')]
potdf.head()
# Out:
#     CASE_ENQUIRY_ID                 OPEN_DT TARGET_DT               CLOSED_DT  \
# 51     101001001808  01/10/2014 04:29:24 AM       NaN  01/10/2014 04:29:25 AM
# 67     101001014109  01/29/2014 08:38:15 AM       NaN  01/29/2014 08:38:15 AM
# 89     101000316327  08/19/2011 11:36:18 AM       NaN  08/19/2011 11:36:19 AM
# 92     101001007126  01/16/2014 03:17:00 PM       NaN  01/16/2014 03:17:01 PM
# 94     101000395943  03/16/2012 09:47:44 AM       NaN  03/16/2012 09:47:44 AM
#
#    OnTime_Status CASE_STATUS CLOSURE_REASON                 CASE_TITLE  \
# 51        ONTIME      Closed            NaN  Pothole Repair (Internal)
# 67        ONTIME      Closed            NaN  Pothole Repair (Internal)
# 89        ONTIME      Closed            NaN  Pothole Repair (Internal)
# 92        ONTIME      Closed            NaN  Pothole Repair (Internal)
# 94        ONTIME      Closed            NaN  Pothole Repair (Internal)
#
#                     SUBJECT               REASON        ...        precinct  \
# 51  Public Works Department  Highway Maintenance        ...            1404
# 67  Public Works Department  Highway Maintenance        ...            0103
# 89  Public Works Department  Highway Maintenance        ...            1803
# 92  Public Works Department  Highway Maintenance        ...            0110
# 94  Public Works Department  Highway Maintenance        ...            0302
#
#    land_usage                    LOCATION_STREET_NAME LOCATION_ZIPCODE  \
# 51        NaN   INTERSECTION Eldon St & Washington St              NaN
# 67        NaN                       172-176 Sumner St           2128.0
# 89        NaN                         143 Colorado St           2126.0
# 92        NaN                      62A-62 Prescott St           2128.0
# 94        NaN  INTERSECTION Commercial St & Foster St              NaN
#
#    Property_Type Property_ID  LATITUDE LONGITUDE              Source  \
# 51           NaN         NaN   42.3029  -71.0782  Employee Generated
# 67           NaN         NaN   42.3694  -71.0406  Employee Generated
# 89           NaN         NaN   42.2755  -71.1018  Employee Generated
# 92           NaN         NaN   42.3789  -71.0295  Employee Generated
# 94           NaN         NaN   42.3677  -71.0540  Employee Generated
#
#    Geocoded_Location
# 51               NaN
# 67               NaN
# 89               NaN
# 92               NaN
# 94               NaN
#
# [5 rows x 33 columns]

# %%
pothole_profile = pdp.ProfileReport(potdf[important_cols])
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /opt/conda/lib/python3.5/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}
# /opt/conda/lib/python3.5/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}

# %%
pothole_profile.to_file(outputfile="pothole_profile.html")

pothole_profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>24 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>77677 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>21.7% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>14.2 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>192.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>4 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>CASE_TITLE</code> has a high cardinality: 116 distinct values  <span class="label label-warning">Warning</span></l><li><code>CLOSURE_REASON</code> has 38442 / 49.5% missing values <span class="label label-default">Missing</span></l><li><code>ClosedPhoto</code> has 68156 / 87.7% missing values <span class="label label-default">Missing</span></l><li><code>ClosedPhoto</code> has a high cardinality: 9522 distinct values  <span class="label label-warning">Warning</span></l><li><code>Geocoded_Location</code> has 77677 / 100.0% missing values <span class="label label-default">Missing</span></l><li><code>Geocoded_Location</code> has constant value  <span class="label label-primary">Rejected</span></l><li><code>Property_Type</code> has 77677 / 100.0% missing values <span class="label label-default">Missing</span></l><li><code>Property_Type</code> has constant value  <span class="label label-primary">Rejected</span></l><li><code>QUEUE</code> has a high cardinality: 97 distinct values  <span class="label label-warning">Warning</span></l><li><code>SubmittedPhoto</code> has 61891 / 79.7% missing values <span class="label label-default">Missing</span></l><li><code>SubmittedPhoto</code> has a high cardinality: 15781 distinct values  <span class="label label-warning">Warning</span></l><li><code>fire_district</code> has 789 / 1.0% missing values <span class="label label-default">Missing</span></l><li><code>land_usage</code> has 77677 / 100.0% missing values <span class="label label-default">Missing</span></l><li><

# %% [markdown]
# # Setup Data Partitions
#
# ### Citizen Reported DF
#
# ### City Worker Reported DF

# %%
# Citizen Reported DF

non_employee_source = ['Citizens Connect App','Constituent Call', 'Self Service', 'Twitter']
citizen_df = potdf.loc[potdf['Source'].isin(non_employee_source) ]

citizen_df.head(1)['Source']
# Out:
# 137    Citizens Connect App
# Name: Source, dtype: object

# %%
# City Worker Reported DF

criterion = lambda row: row['Source'] not in non_employee_source
worker_df = potdf[potdf.apply(criterion, axis=1)]

worker_df.head(1)['Source']
# Out:
# 51    Employee Generated
# Name: Source, dtype: object

# %% [markdown]
# # Potholes by Neigborhood

# %%
# helper methods
import collections

def graph_pots(dd, t=None, yl=None, xl=None):
    l = range(len(dd.keys()))
    plt.bar(l, dd.values(), align='center')
    plt.xticks(l, dd.keys(), rotation='vertical')
    plt.ylabel(yl)
    plt.xlabel(xl)
    plt.title(t)
    plt.show()
    
def graph_col(col_df, col_name):
    return graph_pots(
        collections.Counter(col_df[col_name].dropna())
        )

def potholes_by(hole_df, place, df_name):
    return graph_pots(
        collections.Counter(hole_df[place].dropna()),
        yl='Closed Potholes',
        xl='Places',
        t="Potholes by {} Reported By {}".format(place, df_name)
        )

# %%
df.index
# Out:
# RangeIndex(start=0, stop=973993, step=1)

# %%
potholes_by(potdf, 'neighborhood', 'All')
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
potholes_by(citizen_df, 'neighborhood', 'Citizens')
potholes_by(worker_df, 'neighborhood', 'Workers')
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# # Potholes by City Council District

# %%
potholes_by(potdf, 'city_council_district', 'All')
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
potholes_by(citizen_df, 'city_council_district', 'Citizens')
potholes_by(worker_df, 'city_council_district', 'Workers')
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# # Age of Potholes
#
# 'OPEN_DT', 'TARGET_DT', 'CLOSED_DT'
#
# `age =  DateClosed('CLOSED_DT') - DateCreated('OPEN_DT')`
#
# `expected_age = TargetDate('TARGET_DT') - DateCreate('OPEN_DT') `
#
# `performance = expected_age - age`

# %%
potdf['age'] =  pd.to_datetime(potdf['CLOSED_DT']) - pd.to_datetime(potdf['OPEN_DT'])
potdf['expected_age'] =  pd.to_datetime(potdf['TARGET_DT']) - pd.to_datetime(potdf['OPEN_DT'])
# Datepotdf['performance'] = potdf['expected_age'] - potdf['age']
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# understanding datetimes in pythons
print("Timedelta for a good date vs nan date ")

good_date = potdf.age[51]
nan_date = potdf.age[973808]

print("isinstance(good_date, pd.Timedelta): " + str(isinstance(good_date, pd.Timedelta)))
print("good.__class__ == pd.tslib.Timedelta: " + str(good_date.__class__ == pd.tslib.Timedelta))
try:
    good_date.days
    print("good_date.days")
except:
    good_date.day
    print("good_date.day")
    
print()

print("isinstance(nan_date, pd.Timedelta): " + str(isinstance(nan_date, pd.Timedelta)))
print("nan_date.__class__ == pd.tslib.Timedelta: " + str(nan_date.__class__ == pd.tslib.Timedelta))
try:
    nan_date.days
    print("nan_date.days")
except:
    nan_date.day
    print("nan_date.day")
# Out:
# Timedelta for a good date vs nan date
# isinstance(good_date, pd.Timedelta): True
# good.__class__ == pd.tslib.Timedelta: True
# good_date.days
#
# isinstance(nan_date, pd.Timedelta): False
# nan_date.__class__ == pd.tslib.Timedelta: False
# nan_date.day

# %%
closedpotdf = potdf['age'].dropna()
potdf['age_in_days'] = closedpotdf.apply(lambda x: x.days if isinstance(x, pd.Timedelta) else 0)
# potdf['age_in_days'].dropna()
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# import collections

# # df = df[df.line_race != 0]

# dd = collections.Counter(potdf['neighborhood'].dropna())
# age_dd = collections.Counter(potdf['age_in_days'].dropna())
# age_dd
# # # plt.bar(dd.values(), dd.keys())
# # l = range(len(60)
# plt.hist(x=potdf['age_in_days'], data=potdf['neighborhood'])
# # # plt.xticks(l, age_dd.keys(), rotation='vertical')
# # plt.show()

# %%
potdf['age_in_days'].describe()
# Out:
# count    75510.000000
# mean         2.138803
# std         20.836784
# min         -1.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       1378.000000
# Name: age_in_days, dtype: float64

# %%
# p = potdf['age_in_days'].plot.hist()
# plt.show()

# %%
from collections import defaultdict
age_map = defaultdict(int) 

for age in potdf['age_in_days'].iteritems():
    age_map[age[1]] += 1

# %%
age_map
# Out:
# defaultdict(int,
#             {0.0: 60781,
#              1.0: 5726,
#              2.0: 2267,
#              3.0: 1461,
#              4.0: 849,
#              5.0: 611,
#              6.0: 462,
#              7.0: 279,
#              8.0: 188,
#              9.0: 151,
#              10.0: 151,
#              11.0: 135,
#              12.0: 112,
#              13.0: 100,
#              14.0: 79,
#              15.0: 70,
#              16.0: 62,
#              17.0: 49,
#              18.0: 65,
#              19.0: 49,
#              20.0: 58,
#              21.0: 53,
#              22.0: 23,
#              23.0: 25,
#              24.0: 38,
#              25.0: 28,
#              26.0: 36,
#              27.0: 34,
#              28.0: 35,
#              29.0: 21,
#              30.0: 24,
#              nan: 1,
#              32.0: 20,
#              33.0: 21,
#              34.0: 17,
#              35.0: 13,
#              36.0: 13,
#              37.0: 11,
#              38.0: 8,
#              39.0: 18,
#              40.0: 25,
#              41.0: 15,
#              42.0: 16,
#              43.0: 11,
#              44.0: 6,
#              45.0: 10,
#              46.0: 18,
#              47.0: 14,
#              48.0: 7,
#              49.0: 20,
#              50.0: 15,
#              51.0: 9,
#              52.0: 7,
#              53.0: 23,
#              54.0: 7,
#              55.0: 12,
#              56.0: 8,
#              57.0: 3,
#              58.0: 8,
#              59.0: 9,
#              60.0: 9,
#              61.0: 11,
#              62.0: 3,
#              63.0: 2,
#              64.0: 4,
#              65.0: 10,
#              66.0: 8,
#              67.0: 8,
#              68.0: 9,
#              69.0: 8,
#              70.0: 6,
#              71.0: 7,
#              72.0: 10,
#              73.0: 10,
#              74.0: 5,
#              75.0: 5,
#              76.0: 4,
#              77.0: 8,
#              78.0: 3,
#              79.0: 3,
#              80.0: 2,
#              81.0: 6,
#              82.0: 4,
#              83.0: 1,
#              84.0: 2,
#              85.0: 2,
#              86.0: 2,
#              87.0: 2,
#              88.0: 1,
#              90.0: 6,
#              91.0: 3,
#              92.0: 2,
#              93.0: 1,
#              95.0: 2,
#              96.0: 3,
#              97.0: 3,
#              98.0: 4,
#              99.0: 3,
#              100.0: 1,
#              101.0: 4,
#              102.0: 2,
#              103.0: 1,
#              104.0: 4,
#              105.0: 6,
#              106.0: 2,
#              107.0: 3,
#              108.0: 2,
#              109.0: 1,
#              110.0: 5,
#              111.0: 2,
#              112.0: 5,
#              113.0: 5,
#              114.0: 2,
#              115.0: 1,
#              116.0: 2,
#              118.0: 1,
#              119.0: 1,
#              120.0: 4,
#              121.0: 3,
#              122.0: 4,
#              123.0: 2,
#              124.0: 3,
#              128.0: 2,
#              129.0: 2,
#              nan: 1,
#              131.0: 2,
#              132.0: 2,
#              133.0: 2,
#              134.0: 1,
#              135.0: 2,
#              136.0: 1,
#              137.0: 1,
#              138.0: 1,
#              139.0: 5,
#              140.0: 3,
#              141.0: 4,
#              142.0: 1,
#              143.0: 1,
#              144.0: 2,
#              146.0: 1,
#              147.0: 1,
#              149.0: 1,
#              151.0: 1,
#              152.0: 3,
#              153.0: 4,
#              154.0: 1,
#              nan: 1,
#              nan: 1,
#              157.0: 1,
#              nan: 1,
#              159.0: 1,
#              nan: 1,
#              161.0: 1,
#              163.0: 4,
#              165.0: 2,
#              166.0: 2,
#              167.0: 1,
#              168.0: 1,
#              169.0: 2,
#              170.0: 1,
#              172.0: 2,
#              173.0: 2,
#              nan: 1,
#              175.0: 3,
#              176.0: 1,
#              178.0: 1,
#              180.0: 5,
#              181.0: 5,
#              182.0: 5,
#              183.0: 1,
#              184.0: 1,
#              186.0: 2,
#              31.0: 28,
#              188.0: 1,
#              189.0: 2,
#              nan: 1,
#              nan: 1,
#              195.0: 1,
#              197.0: 1,
#              199.0: 1,
#              nan: 1,
#              201.0: 1,
#              202.0: 1,
#              203.0: 3,
#              204.0: 1,
#              205.0: 1,
#              nan: 1,
#              207.0: 2,
#              208.0: 2,
#              212.0: 3,
#              214.0: 1,
#              215.0: 1,
#              217.0: 3,
#              218.0: 1,
#              219.0: 3,
#              220.0: 1,
#              221.0: 1,
#              222.0: 2,
#              223.0: 4,
#              225.0: 3,
#              226.0: 1,
#              227.0: 2,
#              229.0: 3,
#              230.0: 2,
#              231.0: 2,
#              233.0: 1,
#              234.0: 1,
#              235.0: 2,
#              nan: 1,
#              237.0: 2,
#              238.0: 3,
#              239.0: 1,
#              nan: 1,
#              242.0: 1,
#              243.0: 1,
#              244.0: 3,
#              246.0: 1,
#              248.0: 1,
#              nan: 1,
#              250.0: 1,
#              251.0: 1,
#              253.0: 1,
#              254.0: 1,
#              255.0: 1,
#              256.0: 1,
#              259.0: 1,
#              261.0: 1,
#              262.0: 1,
#              nan: 1,
#              nan: 1,
#              265.0: 1,
#              nan: 1,
#              nan: 1,
#              272.0: 1,
#              273.0: 2,
#              274.0: 1,
#              275.0: 1,
#              276.0: 1,
#              277.0: 1,
#              280.0: 2,
#              281.0: 1,
#              283.0: 1,
#              nan: 1,
#              288.0: 1,
#              nan: 1,
#              291.0: 1,
#              nan: 1,
#              293.0: 1,
#              nan: 1,
#              300.0: 1,
#              nan: 1,
#              307.0: 1,
#              308.0: 1,
#              309.0: 1,
#              nan: 1,
#              nan: 1,
#              315.0: 1,
#              316.0: 1,
#              nan: 1,
#              318.0: 1,
#              320.0: 1,
#              nan: 1,
#              nan: 1,
#              327.0: 1,
#              nan: 1,
#              333.0: 1,
#              335.0: 2,
#              nan: 1,
#              341.0: 1,
#              342.0: 1,
#              343.0: 1,
#              349.0: 1,
#              350.0: 2,
#              353.0: 1,
#              nan: 1,
#              357.0: 1,
#              nan: 1,
#              nan: 1,
#              363.0: 1,
#              365.0: 1,
#              366.0: 1,
#              nan: 1,
#              371.0: 1,
#              372.0: 1,
#              nan: 1,
#              374.0: 1,
#              nan: 1,
#              379.0: 1,
#              380.0: 1,
#              nan: 1,
#              383.0: 1,
#              nan: 1,
#              388.0: 1,
#              389.0: 1,
#              391.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              405.0: 1,
#              406.0: 1,
#              nan: 1,
#              nan: 1,
#              411.0: 1,
#              414.0: 1,
#              416.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              430.0: 1,
#              nan: 1,
#              435.0: 1,
#              445.0: 1,
#              nan: 1,
#              nan: 1,
#              452.0: 1,
#              453.0: 1,
#              nan: 1,
#              455.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              466.0: 1,
#              469.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              479.0: 1,
#              480.0: 1,
#              nan: 1,
#              nan: 1,
#              490.0: 1,
#              491.0: 1,
#              nan: 1,
#              501.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              519.0: 1,
#              nan: 1,
#              nan: 1,
#              526.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              543.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              561.0: 1,
#              nan: 1,
#              565.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              637.0: 1,
#              nan: 1,
#              nan: 1,
#              643.0: 1,
#              647.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              665.0: 1,
#              nan: 1,
#              669.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              695.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              721.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              773.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              814.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              156.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              961.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              991.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              174.0: 2,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              1112.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              187.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              190.0: 2,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              1294.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              1378.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              264.0: 2,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              325.0: 3,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              356.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              373.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              381.0: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              nan: 1,
#              ...})

# %%
non_employee_source = ['Citizens Connect App','Constituent Call', 'Self Service', 'Twitter']
citizens_df = potdf.loc[(potdf['CASE_STATUS'] == 'Closed' ) &(potdf['Source'].isin(non_employee_source)) ]
citizens_df.head()
# Out:
#      CASE_ENQUIRY_ID                 OPEN_DT               TARGET_DT  \
# 137     101001943833  11/02/2016 09:13:00 AM  11/03/2016 09:13:00 AM
# 147     101001995955  01/25/2017 08:23:12 AM  01/26/2017 08:30:00 AM
# 257     101002012985  02/14/2017 11:51:00 AM  02/15/2017 11:51:27 AM
# 393     101001346580  04/01/2015 09:31:49 AM  04/02/2015 09:31:49 AM
# 413     101000367313  12/23/2011 08:09:26 AM  12/27/2011 08:09:26 AM
#
#                   CLOSED_DT OnTime_Status CASE_STATUS CLOSURE_REASON  \
# 137  11/08/2016 01:41:56 PM       OVERDUE      Closed  Case Resolved
# 147  01/26/2017 12:37:23 PM       OVERDUE      Closed   Case Invalid
# 257  02/27/2017 01:00:03 PM       OVERDUE      Closed     Case Noted
# 393  04/01/2015 11:30:44 AM        ONTIME      Closed  Case Resolved
# 413  12/23/2011 10:24:53 AM        ONTIME      Closed  Case Resolved
#
#                      CASE_TITLE                  SUBJECT               REASON  \
# 137  Request for Pothole Repair  Public Works Department  Highway Maintenance
# 147  Request for Pothole Repair  Public Works Department  Highway Maintenance
# 257  Request for Pothole Repair  Public Works Department  Highway Maintenance
# 393  Request for Pothole Repair  Public Works Department  Highway Maintenance
# 413  Request for Pothole Repair  Public Works Department  Highway Maintenance
#
#         ...     LOCATION_ZIPCODE Property_Type Property_ID LATITUDE LONGITUDE  \
# 137     ...                  NaN           NaN         NaN  42.3594  -71.0587
# 147     ...               2116.0           NaN         NaN  42.3485  -71.0680
# 257     ...                  NaN           NaN         NaN  42.3594  -71.0587
# 393     ...               2127.0           NaN         NaN  42.3439  -71.0567
# 413     ...               2119.0           NaN         NaN  42.3284  -71.0898
#
#                    Source  Geocoded_Location              age    expected_age  \
# 137  Citizens Connect App                NaN  6 days 04:28:56 1 days 00:00:00
# 147  Citizens Connect App                NaN  1 days 04:14:11 1 days 00:06:48
# 257      Constituent Call                NaN 13 days 01:09:03 1 days 00:00:27
# 393  Citizens Connect App                NaN  0 days 01:58:55 1 days 00:00:00
# 413  Citizens Connect App                NaN  0 days 02:15:27 4 days 00:00:00
#
#     age_in_days
# 137         6.0
# 147         1.0
# 257        13.0
# 393         0.0
# 413         0.0
#
# [5 rows x 36 columns]

# %%
citizens_age = defaultdict(int) 

for age in citizens_df['age_in_days'].iteritems():
    citizens_age[age[1]] += 1
    
citizens_age

top_n = 40
age_keys = sorted(citizens_age.keys())

print("first {} days:\n".format(top_n))
for i in age_keys[:top_n]:
    print(i, citizens_age[i])
    
print()

bottom_n = 5
print("last {} days:\n".format(bottom_n))
for i in age_keys[len(age_keys) - bottom_n:]:
    print(i, citizens_age[i])
# Out:
# first 40 days:
#
# 0.0 8874
# 1.0 3333
# 2.0 1795
# 3.0 1113
# 4.0 652
# 5.0 438
# 6.0 359
# 7.0 204
# 8.0 144
# 9.0 109
# 10.0 117
# 11.0 112
# 12.0 94
# 13.0 83
# 14.0 61
# 15.0 60
# 16.0 47
# 17.0 38
# 18.0 47
# 19.0 42
# 20.0 51
# 21.0 35
# 22.0 22
# 23.0 23
# 24.0 21
# 25.0 22
# 26.0 31
# 27.0 33
# 28.0 30
# 29.0 18
# 30.0 22
# 31.0 24
# 32.0 16
# 33.0 17
# 34.0 13
# 35.0 10
# 36.0 13
# 37.0 9
# 38.0 8
# 39.0 18
#
# last 5 days:
#
# 961.0 1
# 991.0 1
# 1112.0 1
# 1294.0 1
# 1378.0 1

# %% [markdown]
# # Picking arbitray cut off
#
# Essentially, we have a long tail. We should try different cut offs. But figure out what those % are.}

# %% [markdown]
# ## cumulative_days

# %%
cumulative_days =  defaultdict(int) 
seen = []
for k in age_keys:
    seen.append(k)
    for older in seen:
        cumulative_days[k] += citizens_age[older]

for i in range(45):
    print(i, cumulative_days[i])
# Out:
# 0 8874
# 1 12207
# 2 14002
# 3 15115
# 4 15767
# 5 16205
# 6 16564
# 7 16768
# 8 16912
# 9 17021
# 10 17138
# 11 17250
# 12 17344
# 13 17427
# 14 17488
# 15 17548
# 16 17595
# 17 17633
# 18 17680
# 19 17722
# 20 17773
# 21 17808
# 22 17830
# 23 17853
# 24 17874
# 25 17896
# 26 17927
# 27 17960
# 28 17990
# 29 18008
# 30 18030
# 31 18054
# 32 18070
# 33 18087
# 34 18100
# 35 18110
# 36 18123
# 37 18132
# 38 18140
# 39 18158
# 40 18182
# 41 18197
# 42 18210
# 43 18218
# 44 18223

# %%
# Day by Cumulative Number of Closed Potholes

x1 = []
y1 = []
for date in cumulative_days:
    x1.append(date)
    y1.append(cumulative_days[date])
plt.ylabel('closed potholes')
plt.xlabel('days_old')
plt.title('Cumulative Number of Closed Potholes by Day')
plt.bar(x1, y1)
plt.show()
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
n = citizens_df.shape[0]
print("N examples: "+str(n))
# Out:
# N examples: 18804

# %%
percent_by_day =  defaultdict(int) 
seen = []
for k in cumulative_days:
    percent_by_day[k] = cumulative_days[k]/n

percent_by_day  

for i in range(25): # 95% percentile
    print(i, percent_by_day[i])
# Out:
# 0 0.47192086790044674
# 1 0.6491703892788768
# 2 0.7446288023824719
# 3 0.8038183365241438
# 4 0.8384918102531377
# 5 0.8617847266539034
# 6 0.8808764092746224
# 7 0.8917251648585407
# 8 0.8993831099766008
# 9 0.9051797489895766
# 10 0.9114018293980004
# 11 0.9173580089342693
# 12 0.9223569453307807
# 13 0.9267708998085513
# 14 0.9300148904488407
# 15 0.933205700914699
# 16 0.9357051691129546
# 17 0.9377260157413316
# 18 0.9402254839395873
# 19 0.9424590512656882
# 20 0.9451712401616678
# 21 0.9470325462667517
# 22 0.9482025101042332
# 23 0.9494256541161455
# 24 0.9505424377791959

# %%
# compute_percent_changes_points
prev = 0.0

change_pts = []
change_chart = {}
for indx in percent_by_day:
    current = (percent_by_day[indx] * 100)
    if (current - prev >= 1) and (current != 0):
        change_pts.append(indx)
        print("CHANGE @ {} current:{} prev:{}".format(indx,current, prev))
        prev = current
        
        
percent_by_day[31]
# Out:
# CHANGE @ 0.0 current:47.19208679004468 prev:0.0
# CHANGE @ 1.0 current:64.91703892788769 prev:47.19208679004468
# CHANGE @ 2.0 current:74.46288023824718 prev:64.91703892788769
# CHANGE @ 3.0 current:80.38183365241439 prev:74.46288023824718
# CHANGE @ 4.0 current:83.84918102531377 prev:80.38183365241439
# CHANGE @ 5.0 current:86.17847266539033 prev:83.84918102531377
# CHANGE @ 6.0 current:88.08764092746225 prev:86.17847266539033
# CHANGE @ 7.0 current:89.17251648585408 prev:88.08764092746225
# CHANGE @ 9.0 current:90.51797489895766 prev:89.17251648585408
# CHANGE @ 11.0 current:91.73580089342693 prev:90.51797489895766
# CHANGE @ 14.0 current:93.00148904488407 prev:91.73580089342693
# CHANGE @ 18.0 current:94.02254839395873 prev:93.00148904488407
# CHANGE @ 24.0 current:95.0542437779196 prev:94.02254839395873
# CHANGE @ 32.0 current:96.09657519676664 prev:95.0542437779196
# CHANGE @ 48.0 current:97.11763454584131 prev:96.09657519676664
# CHANGE @ 73.0 current:98.13337587747287 prev:97.11763454584131
# CHANGE @ 637.0 current:99.93086577323974 prev:98.13337587747287
# 0.9601148691767709

# %%
age_by_percent_x = [percent_by_day[pt] for pt in change_pts]
# percent_by_day.keys()
# change_pts
# age_by_percent_xp
plt.plot(change_pts,age_by_percent_x)
plt.ylabel('% closed potholes ')
plt.xlabel('days_old')
plt.title('Potholes close days 0-100%')
plt.show()
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
day_20s = list(filter(lambda x: x < 20, change_pts))
day_20_drop_off = [percent_by_day[pt] for pt in day_20s] 

plt.plot(day_20s,day_20_drop_off)
plt.ylabel('% closed potholes')
plt.xlabel('days_old')
plt.title('% Potholes close in first days')
plt.show()
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
cut_off = 24 # 99

for i in range(170, 175): # 95% percentile
    print(i, percent_by_day[i])
# Out:
# 170 0.9910125505211657
# 171 0
# 172 0.9911189108700277
# 173 0.9911720910444586
# 174 0.9912252712188896

# %%
cut_off_dates = [25, 73]
for cut_off in cut_off_dates:
    x = []
    y = []
    for date in range(cut_off):
        x.append(citizens_age[date])
        y.append(date)
    plt.bar( y, x, log=False)
    plt.ylabel('closed potholes')
    plt.xlabel('days_old')
    plt.title('Cut off of {} '.format(cut_off))
    plt.show()
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
citizens_age
# Out:
# defaultdict(int,
#             {0.0: 8874,
#              1.0: 3333,
#              2.0: 1795,
#              3.0: 1113,
#              4.0: 652,
#              5.0: 438,
#              6.0: 359,
#              7.0: 204,
#              8.0: 144,
#              9.0: 109,
#              10.0: 117,
#              11.0: 112,
#              12.0: 94,
#              13.0: 83,
#              14.0: 61,
#              15.0: 60,
#              16.0: 47,
#              17.0: 38,
#              18.0: 47,
#              19.0: 42,
#              20.0: 51,
#              21.0: 35,
#              22.0: 22,
#              23.0: 23,
#              24.0: 21,
#              25.0: 22,
#              26.0: 31,
#              27.0: 33,
#              28.0: 30,
#              29.0: 18,
#              30.0: 22,
#              31.0: 24,
#              32.0: 16,
#              33.0: 17,
#              34.0: 13,
#              35.0: 10,
#              36.0: 13,
#              37.0: 9,
#              38.0: 8,
#              39.0: 18,
#              40.0: 24,
#              41.0: 15,
#              42.0: 13,
#              43.0: 8,
#              44.0: 5,
#              45.0: 9,
#              46.0: 13,
#              47.0: 11,
#              48.0: 6,
#              49.0: 12,
#              50.0: 11,
#              51.0: 9,
#              52.0: 5,
#              53.0: 20,
#              54.0: 7,
#              55.0: 11,
#              56.0: 5,
#              57.0: 1,
#              58.0: 8,
#              59.0: 8,
#              60.0: 7,
#              61.0: 11,
#              62.0: 3,
#              63.0: 2,
#              64.0: 4,
#              65.0: 9,
#              66.0: 7,
#              67.0: 6,
#              68.0: 9,
#              69.0: 8,
#              70.0: 5,
#              71.0: 6,
#              72.0: 8,
#              73.0: 9,
#              74.0: 5,
#              75.0: 4,
#              76.0: 2,
#              77.0: 7,
#              78.0: 2,
#              79.0: 3,
#              80.0: 1,
#              81.0: 6,
#              82.0: 3,
#              83.0: 1,
#              84.0: 2,
#              85.0: 2,
#              86.0: 2,
#              87.0: 2,
#              88.0: 1,
#              90.0: 4,
#              91.0: 2,
#              92.0: 2,
#              93.0: 1,
# 973902                     Case Resolved  Request for Pothole Repair
# 973907                     Case Resolved  Request for Pothole Repair
# 973967                        Case Noted  Request for Pothole Repair
# 973979                        Case Noted  Request for Pothole Repair
# 973982                     Case Resolved  Request for Pothole Repair
#
#                         SUBJECT               REASON     ...      \
# 137     Public Works Department  Highway Maintenance     ...
# 147     Public Works Department  Highway Maintenance     ...
# 257     Public Works Department  Highway Maintenance     ...
# 393     Public Works Department  Highway Maintenance     ...
# 413     Public Works Department  Highway Maintenance     ...
# 524     Public Works Department  Highway Maintenance     ...
# 582     Public Works Department  Highway Maintenance     ...
# 609     Public Works Department  Highway Maintenance     ...
# 612     Public Works Department  Highway Maintenance     ...
# 756     Public Works Department  Highway Maintenance     ...
# 796     Public Works Department  Highway Maintenance     ...
# 809     Public Works Department  Highway Maintenance     ...
# 913     Public Works Department  Highway Maintenance     ...
# 933     Public Works Department  Highway Maintenance     ...
# 991     Public Works Department  Highway Maintenance     ...
# 1017    Public Works Department  Highway Maintenance     ...
# 1035    Public Works Department  Highway Maintenance     ...
# 1217    Public Works Department  Highway Maintenance     ...
# 1230    Public Works Department  Highway Maintenance     ...
# 1261    Public Works Department  Highway Maintenance     ...
# 1317    Public Works Department  Highway Maintenance     ...
# 1357    Public Works Department  Highway Maintenance     ...
# 1454    Public Works Department  Highway Maintenance     ...
# 1467    Public Works Department  Highway Maintenance     ...
# 1526    Public Works Department  Highway Maintenance     ...
# 1562    Public Works Department  Highway Maintenance     ...
# 1654    Public Works Department  Highway Maintenance     ...
# 1716    Public Works Department  Highway Maintenance     ...
# 1764    Public Works Department  Highway Maintenance     ...
# 1874    Public Works Department  Highway Maintenance     ...
# ...                         ...                  ...     ...
# 973423  Public Works Department  Highway Maintenance     ...
# 973440  Public Works Department  Highway Maintenance     ...
# 973447  Public Works Department  Highway Maintenance     ...
# 973452  Public Works Department  Highway Maintenance     ...
# 973461  Public Works Department  Highway Maintenance     ...
# 973513  Public Works Department  Highway Maintenance     ...
# 973526  Public Works Department  Highway Maintenance     ...
# 973554  Public Works Department  Highway Maintenance     ...
# 973643  Public Works Department  Highway Maintenance     ...
# 973657  Public Works Department  Highway Maintenance     ...
# 973696  Public Works Department  Highway Maintenance     ...
# 973713  Public Works Department  Highway Maintenance     ...
# 973720  Public Works Department  Highway Maintenance     ...
# 973721  Public Works Department  Highway Maintenance     ...
# 973723  Public Works Department  Highway Maintenance     ...
# 973733  Public Works Department  Highway Maintenance     ...
# 973734  Public Works Department  Highway Maintenance     ...
# 973750  Public Works Department  Highway Maintenance     ...
# 973764  Public Works Department  Highway Maintenance     ...
# 973777  Public Works Department  Highway Maintenance     ...
# 973793  Public Works Department  Highway Maintenance     ...
# 973815  Public Works Department  Highway Maintenance     ...
# 973831  Public Works Department  Highway Maintenance     ...
# 973843  Public Works Department  Highway Maintenance     ...
# 973887  Public Works Department  Highway Maintenance     ...
# 973902  Public Works Department  Highway Maintenance     ...
# 973907  Public Works Department  Highway Maintenance     ...
# 973967  Public Works Department  Highway Maintenance     ...
