# %% [markdown]
# # City of Boston 311 Data Exploration
#
# Digging into what data is on 311, Service RequestsCity Services
# https://data.cityofboston.gov/City-Services/311-Service-Requests/awu8-dc52

# %%
import pandas as pd
import pandas_profiling as pdp
import matplotlib
import matplotlib.pyplot as plt


# %matplotlib inline
# Out:
# ERROR:root:Line magic function `%inline` not found.

# %% [markdown]
# # Load Data
#
# https://data.cityofboston.gov/City-Services/311-Service-Requests/awu8-dc52

# %%
df=pd.read_csv("../../data/311__Service_Requests.csv", parse_dates=True, encoding='UTF-8', infer_datetime_format=True)

# %%
df.head()
# Out:
#    CASE_ENQUIRY_ID                 OPEN_DT               TARGET_DT  \
# 0     101000493034  10/16/2012 02:45:25 PM  10/18/2012 02:45:24 PM
# 1     101000362571  12/09/2011 04:04:25 PM                     NaN
# 2     101000301154  07/13/2011 11:40:05 AM  07/15/2011 11:40:05 AM
# 3     101000339191  10/06/2011 02:59:01 PM  10/13/2011 02:59:01 PM
# 4     101000409680  04/18/2012 11:39:15 AM  10/15/2012 11:39:15 AM
#
#                 CLOSED_DT OnTime_Status CASE_STATUS CLOSURE_REASON  \
# 0  10/17/2012 07:36:59 AM        ONTIME      Closed  Case Resolved
# 1  12/19/2011 11:50:23 PM        ONTIME      Closed            NaN
# 2  02/09/2012 04:16:40 PM       OVERDUE      Closed            NaN
# 3  10/12/2011 08:41:41 AM        ONTIME      Closed  Case Resolved
# 4  04/19/2012 09:23:17 AM        ONTIME      Closed  Case Resolved
#
#                     CASE_TITLE                  SUBJECT               REASON  \
# 0              Sticker Request  Public Works Department            Recycling
# 1  Schedule a Bulk Item Pickup  Public Works Department           Sanitation
# 2            Work w/out Permit    Inspectional Services             Building
# 3        Contractor Complaints  Public Works Department  Highway Maintenance
# 4    Upgrade Existing Lighting  Public Works Department        Street Lights
#
#          ...        precinct land_usage LOCATION_STREET_NAME LOCATION_ZIPCODE  \
# 0        ...            1602        NaN           36 Park St           2122.0
# 1        ...            2210        NaN         89 Turner St           2135.0
# 2        ...            1906        NaN        626 Centre St           2130.0
# 3        ...            2213        NaN      50-52 Burton St           2135.0
# 4        ...            0303        NaN       204 Hanover St           2113.0
#
#   Property_Type Property_ID  LATITUDE LONGITUDE              Source  \
# 0           NaN         NaN   42.3011  -71.0543        Self Service
# 1           NaN         NaN   42.3523  -71.1618        Self Service
# 2           NaN         NaN   42.3139  -71.1138    Constituent Call
# 3           NaN         NaN   42.3550  -71.1721    Constituent Call
# 4           NaN         NaN   42.3628  -71.0557  Maximo Integration
#
#   Geocoded_Location
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['CASE_ENQUIRY_ID', 'OPEN_DT', 'TARGET_DT', 'CLOSED_DT', 'OnTime_Status',
#        'CASE_STATUS', 'CLOSURE_REASON', 'CASE_TITLE', 'SUBJECT', 'REASON',
#        'TYPE', 'QUEUE', 'Department', 'SubmittedPhoto', 'ClosedPhoto',
#        'Location', 'fire_district', 'pwd_district', 'city_council_district',
#        'police_district', 'neighborhood', 'neighborhood_services_district',
#        'ward', 'precinct', 'land_usage', 'LOCATION_STREET_NAME',
#        'LOCATION_ZIPCODE', 'Property_Type', 'Property_ID', 'LATITUDE',
#        'LONGITUDE', 'Source', 'Geocoded_Location'],
#       dtype='object')

# %%
df.describe()
# Out:
#        CASE_ENQUIRY_ID  fire_district  city_council_district  \
# count     9.739930e+05  930126.000000          933309.000000
# mean      1.010013e+11       7.129086               4.646184
# std       5.355242e+05       3.260521               2.575545
# min       1.010003e+11       1.000000               0.000000
# 25%       1.010009e+11       4.000000               2.000000
# 50%       1.010013e+11       7.000000               5.000000
# 75%       1.010018e+11       9.000000               7.000000
# max       1.010021e+11      12.000000               9.000000
#
#        neighborhood_services_district  land_usage  LOCATION_ZIPCODE  \
# count                   933302.000000         0.0     743564.000000
# mean                         8.910798         NaN       2127.357854
# std                          4.204147         NaN         18.074524
# min                          0.000000         NaN       2026.000000
# 25%                          5.000000         NaN       2120.000000
# 50%                         10.000000         NaN       2126.000000
# 75%                         13.000000         NaN       2131.000000
# max                         15.000000         NaN       2467.000000
#
#        Property_Type  Property_ID       LATITUDE      LONGITUDE  \
# count            0.0          0.0  973993.000000  973993.000000
# mean             NaN          NaN      42.326995     -71.083624
# std              NaN          NaN       0.034722       0.035737
# min              NaN          NaN      42.230200     -71.185400
# 25%              NaN          NaN      42.296700     -71.107600
# 50%              NaN          NaN      42.334600     -71.073300
# 75%              NaN          NaN      42.359400     -71.058700
# max              NaN          NaN      42.395200     -70.994900
#
#        Geocoded_Location
# count                0.0
# mean                 NaN
# std                  NaN
# min                  NaN
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max                  NaN

# %%
# noisey_cols = ['LATITUDE', 'OPEN_DT', 'TARGET_DT','CLOSED_DT', 'CASE_ENQUIRY_ID', 'Location', 'LOCATION_STREET_NAME', 'Property_ID', 'LATITUDE','LONGITUDE', 'LOCATION_ZIPCODE', ]
# pdp.ProfileReport(df[df.columns.difference(noisey_cols)])
important_cols = ['OnTime_Status',
       'CASE_STATUS', 'CLOSURE_REASON', 'CASE_TITLE', 'SUBJECT', 'REASON',
       'TYPE', 'QUEUE', 'Department', 'SubmittedPhoto', 'ClosedPhoto'
       , 'fire_district', 'pwd_district', 'city_council_district',
       'police_district', 'neighborhood', 'neighborhood_services_district',
       'ward', 'precinct', 'land_usage', 'Property_Type', 'Source', 'Geocoded_Location']
profile = pdp.ProfileReport(df[important_cols])
# Out:
# /opt/conda/lib/python3.5/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}
# /opt/conda/lib/python3.5/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}
# /opt/conda/lib/python3.5/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}

# %%
profile.to_file(outputfile="full_profile.html")
profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>23 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>973993 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>23.3% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>170.9 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>184.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>4 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>CASE_TITLE</code> has a high cardinality: 10921 distinct values  <span class="label label-warning">Warning</span></l><li><code>CLOSURE_REASON</code> has 307931 / 31.6% missing values <span class="label label-default">Missing</span></l><li><code>ClosedPhoto</code> has 883321 / 90.7% missing values <span class="label label-default">Missing</span></l><li><code>ClosedPhoto</code> has a high cardinality: 90673 distinct values  <span class="label label-warning">Warning</span></l><li><code>Geocoded_Location</code> has 973993 / 100.0% missing values <span class="label label-default">Missing</span></l><li><code>Geocoded_Location</code> has constant value  <span class="label label-primary">Rejected</span></l><li><code>Property_Type</code> has 973993 / 100.0% missing values <span class="label label-default">Missing</span></l><li><code>Property_Type</code> has constant value  <span class="label label-primary">Rejected</span></l><li><code>QUEUE</code> has a high cardinality: 204 distinct values  <span class="label label-warning">Warning</span></l><li><code>REASON</code> has a high cardinality: 61 distinct values  <span class="label label-warning">Warning</span></l><li><code>SubmittedPhoto</code> has 812004 / 83.4% missing values <span class="label label-default">Missing</span></l><li><code>SubmittedPhoto</code> has a high cardinality: 161787 distinct values  <span class="label label-warning">Warning</span></l><li><code>TYPE</code> has a high cardinality: 216 distinct values  <span class="label label-warning"

# %%
potdf = df.loc[df['TYPE'].str.contains('Pot')]
potdf
# Out:
#         CASE_ENQUIRY_ID                 OPEN_DT               TARGET_DT  \
# 51         101001001808  01/10/2014 04:29:24 AM                     NaN
# 67         101001014109  01/29/2014 08:38:15 AM                     NaN
# 89         101000316327  08/19/2011 11:36:18 AM                     NaN
# 92         101001007126  01/16/2014 03:17:00 PM                     NaN
# 94         101000395943  03/16/2012 09:47:44 AM                     NaN
# 107        101000855259  06/07/2013 12:06:06 PM                     NaN
# 124        101000410123  04/19/2012 09:32:24 AM  04/23/2012 09:32:24 AM
# 137        101001943833  11/02/2016 09:13:00 AM  11/03/2016 09:13:00 AM
# 147        101001995955  01/25/2017 08:23:12 AM  01/26/2017 08:30:00 AM
# 151        101000398587  03/22/2012 09:11:07 AM  03/26/2012 09:11:07 AM
# 154        101000503763  11/06/2012 02:04:16 PM  11/08/2012 02:04:15 PM
# 174        101001042881  03/07/2014 03:09:06 PM                     NaN
# 179        101000788775  02/21/2013 01:08:27 PM                     NaN
# 203        101000933879  09/25/2013 09:05:50 AM  09/27/2013 09:05:50 AM
# 207        101001112627  06/20/2014 12:56:40 PM                     NaN
# 211        101000419338  05/09/2012 01:44:49 PM  05/11/2012 01:44:48 PM
# 252        101002021150  02/21/2017 12:26:56 PM  02/22/2017 12:26:56 PM
# 253        101001035726  02/25/2014 09:34:12 AM  02/27/2014 09:34:12 AM
# 257        101002012985  02/14/2017 11:51:00 AM  02/15/2017 11:51:27 AM
# 266        101001789355  05/13/2016 10:00:21 AM  05/16/2016 10:00:21 AM
# 276        101001015527  01/30/2014 02:48:04 PM                     NaN
# 285        101001015338  01/30/2014 02:08:49 PM                     NaN
# 287        101000976015  12/04/2013 07:23:02 AM  12/06/2013 08:30:00 AM
# 289        101001036714  02/26/2014 11:00:43 AM  02/28/2014 11:00:42 AM
# 51      01/10/2014 04:29:25 AM        ONTIME      Closed            NaN
# 67      01/29/2014 08:38:15 AM        ONTIME      Closed            NaN
# 89      08/19/2011 11:36:19 AM        ONTIME      Closed            NaN
# 92      01/16/2014 03:17:01 PM        ONTIME      Closed            NaN
# 94      03/16/2012 09:47:44 AM        ONTIME      Closed            NaN
# 107     06/07/2013 12:06:06 PM        ONTIME      Closed            NaN
# 124     04/19/2012 09:32:28 AM        ONTIME      Closed            NaN
# 137     11/08/2016 01:41:56 PM       OVERDUE      Closed  Case Resolved
# 147     01/26/2017 12:37:23 PM       OVERDUE      Closed   Case Invalid
# 151     03/23/2012 12:34:45 PM        ONTIME      Closed  Case Resolved
# 154     11/07/2012 10:23:29 AM        ONTIME      Closed  Case Resolved
# 174     03/07/2014 03:09:07 PM        ONTIME      Closed            NaN
# 179     02/21/2013 01:08:28 PM        ONTIME      Closed            NaN
# 203     09/25/2013 12:01:28 PM        ONTIME      Closed  Case Resolved
# 207     06/20/2014 12:56:40 PM        ONTIME      Closed            NaN
# 211     05/10/2012 03:10:06 PM        ONTIME      Closed  Case Resolved
# 252     02/21/2017 12:26:58 PM        ONTIME      Closed  Case Resolved
# 253     02/25/2014 10:51:58 AM        ONTIME      Closed  Case Resolved
# 257     02/27/2017 01:00:03 PM       OVERDUE      Closed     Case Noted
# 266     05/13/2016 10:00:23 AM        ONTIME      Closed  Case Resolved
# 276     01/30/2014 02:48:05 PM        ONTIME      Closed            NaN
# 285     01/30/2014 02:08:49 PM        ONTIME      Closed            NaN
# 287     12/04/2013 11:50:58 AM        ONTIME      Closed  Case Resolved
# 289     02/26/2014 11:00:46 AM        ONTIME      Closed  Case Resolved
# 306     02/07/2014 08:20:19 AM        ONTIME      Closed            NaN
# 312     05/16/2012 01:34:44 PM        ONTIME      Closed            NaN
# 316     07/11/2011 08:22:22 AM        ONTIME      Closed            NaN
# 318     08/23/2013 09:55:31 AM        ONTIME      Closed            NaN
# 328     05/06/2014 03:35:40 PM        ONTIME      Closed            NaN
# 337     03/13/2015 12:53:16 PM        ONTIME      Closed  Case Resolved
# ...                        ...           ...         ...            ...
# 973721  04/11/2017 01:37:32 PM        ONTIME      Closed  Case Resolved
# 973722                     NaN       OVERDUE        Open            NaN
# 973723  04/11/2017 01:04:02 PM       OVERDUE      Closed  Case Resolved
# 973729                     NaN       OVERDUE        Open            NaN
# 973733  04/11/2017 01:16:16 PM       OVERDUE      Closed  Case Resolved
# 973734  04/11/2017 12:16:51 PM        ONTIME      Closed  Case Resolved
# 973750  04/11/2017 10:30:53 AM        ONTIME      Closed  Case Resolved
# 973764  04/11/2017 06:08:57 AM       OVERDUE      Closed  Case Resolved
# 973766                     NaN       OVERDUE        Open            NaN
# 973777  04/11/2017 11:55:44 AM       OVERDUE      Closed  Case Resolved
# 973789                     NaN        ONTIME        Open            NaN
# 973793  04/11/2017 10:30:16 AM       OVERDUE      Closed  Case Resolved
# 973789  Highway Maintenance        ...            0306        NaN
# 973793  Highway Maintenance        ...            0901        NaN
# 973795  Highway Maintenance        ...            0404        NaN
# 973808  Highway Maintenance        ...            0605        NaN
# 973815  Highway Maintenance        ...            0306        NaN
# 973821  Highway Maintenance        ...            2106        NaN
# 973831  Highway Maintenance        ...            2102        NaN
# 973843  Highway Maintenance        ...            0306        NaN
# 973887  Highway Maintenance        ...            0306        NaN
# 973897  Highway Maintenance        ...            1818        NaN
# 973902  Highway Maintenance        ...            0802        NaN
# 973907  Highway Maintenance        ...            1902        NaN
# 973928  Highway Maintenance        ...            0409        NaN
# 973936  Highway Maintenance        ...            0410        NaN
# 973947  Highway Maintenance        ...            2207        NaN
# 973967  Highway Maintenance        ...            2015        NaN
# 973974  Highway Maintenance        ...            0402        NaN
# 973979  Highway Maintenance        ...            1401        NaN
# 973982  Highway Maintenance        ...            0508        NaN
# 973989  Highway Maintenance        ...            0111        NaN
#
#                                    LOCATION_STREET_NAME LOCATION_ZIPCODE  \
# 51                INTERSECTION Eldon St & Washington St              NaN
# 67                                    172-176 Sumner St           2128.0
# 89                                      143 Colorado St           2126.0
# 92                                   62A-62 Prescott St           2128.0
# 94               INTERSECTION Commercial St & Foster St              NaN
# 107                                  5098 Washington St           2132.0
# 124               INTERSECTION Quint Ave & Radcliffe Rd              NaN
# 137             INTERSECTION Kingsdale St & Standish St              NaN
# 147                                       42 Fayette St           2116.0
# 151                                      294 Hanover St           2113.0
# 154          INTERSECTION Dorchester Ave & Greenbaum St              NaN
# 174            INTERSECTION Fletcher St & Montclair Ave              NaN
# 179                                  2371 Washington St           2119.0
# 203                                      85 Taunton Ave           2126.0
# 207                                        360 South St           2131.0
# 211                                      74 Halliday St           2131.0
# 252                INTERSECTION Charlesgate & Beacon St              NaN
# 253                                   0 Forest Hills St           2130.0
# 257        INTERSECTION Melnea Cass Blvd & Harrison Ave              NaN
# 266             INTERSECTION Blue Hills Pkwy & River St              NaN
# 276              INTERSECTION Geneva Ave & Josephine St              NaN
# 285                                         45 Adams St           2122.0
# 287                      INTERSECTION W Broadway & F St              NaN
# 289                                   640 Washington St           2135.0
# 306                                       27 Dixwell St           2119.0
# 312                               411-413 Washington St           2124.0
# 316                                           6 Rowe St           2131.0
# 318                                          71 Dale St           2119.0
# 328                                   58 Bradstreet Ave           2131.0
# 337             INTERSECTION Columbia Rd & E Cottage St              NaN
# ...                                                 ...              ...
# 973721                          530 American Legion Hwy           2131.0
# 973722               INTERSECTION Medfield St & Park Dr              NaN
# 973723  INTERSECTION Massachusetts Ave & Huntington Ave              NaN
# 973729                                    9-11 Knapp St           2111.0
# 973733                                      31 Essex St           2111.0
# 973734                                   15 Hatherly Rd           2135.0
# 973750                                  52 Paul Gore St           2130.0
# 973764                                      55 Fruit St           2114.0
# 973766                                   75 Boylston St           2108.0
# 973777            INTERSECTION Milford St & Bradford St              NaN
# 973789           INTERSECTION Franklin St & Congress St              NaN
# 973793                                    79 Rutland St           2118.0
# 973795                                 551 Columbus Ave           2118.0
# 973808                  INTERSECTION K St & E Second St              NaN
# 973815                                 69-81 Tremont St           2108.0
# 973821         INTERSECTION Cambridge St & Brighton Ave              NaN
# 973831               INTERSECTION Arundel St & Miner St              NaN
# 973843                               45 Batterymarch St           2110.0
# 973887                                     13 Temple St           2114.0
# 973897                               1406 Hyde Park Ave           2136.0
# 973902                               274 Southampton St           2118.0
# 973907                                   25 Parkside Dr           2130.0
# 973928        INTERSECTION Fencourt St & Huntington Ave              NaN
# 973936                           635-641 Huntington Ave           2115.0
# 973947                                     18 Hobson St           2135.0
# 973967                                      9 Grove Ter           2132.0
# 973974        INTERSECTION Trinity Pl & Saint James Ave              NaN
# 973979                            460-468 Blue Hill Ave           2121.0
# 973982                                  12 Fairfield St           2116.0
# 973989                                540 Bennington St           2128.0
#
#        Property_Type Property_ID  LATITUDE LONGITUDE                Source  \
# 51               NaN         NaN   42.3029  -71.0782    Employee Generated
# 67               NaN         NaN   42.3694  -71.0406    Employee Generated
# 89               NaN         NaN   42.2755  -71.1018    Employee Generated
# 92               NaN         NaN   42.3789  -71.0295    Employee Generated
# 94               NaN         NaN   42.3677  -71.0540    Employee Generated
# 107              NaN         NaN   42.2638  -71.1540    Employee Generated
# 124              NaN         NaN   42.3508  -71.1336       City Worker App
# 137              NaN         NaN   42.3594  -71.0587  Citizens Connect App
# 147              NaN         NaN   42.3485  -71.0680  Citizens Connect App
# 151              NaN         NaN   42.3641  -71.0544       City Worker App
# 154              NaN         NaN   42.3427  -71.0572       City Worker App
# 174              NaN         NaN   42.2918  -71.1406    Employee Generated
# 179              NaN         NaN   42.3293  -71.0850    Employee Generated
# 203              NaN         NaN   42.2665  -71.1054       City Worker App
# 207              NaN         NaN   42.3594  -71.0587    Employee Generated
# 211              NaN         NaN   42.2885  -71.1126       City Worker App
# 252              NaN         NaN   42.3594  -71.0587       City Worker App
# 253              NaN         NaN   42.3594  -71.0587       City Worker App
# 257              NaN         NaN   42.3594  -71.0587      Constituent Call
# 266              NaN         NaN   42.3594  -71.0587       City Worker App
# 276              NaN         NaN   42.3002  -71.0661    Employee Generated
# 285              NaN         NaN   42.3071  -71.0626    Employee Generated
# 287              NaN         NaN   42.3368  -71.0478       City Worker App
# 289              NaN         NaN   42.3507  -71.1692       City Worker App
# 306              NaN         NaN   42.3143  -71.0982    Employee Generated
# 312              NaN         NaN   42.2972  -71.0727    Employee Generated
# 316              NaN         NaN   42.2845  -71.1203    Employee Generated
# 318              NaN         NaN   42.3216  -71.0860    Employee Generated
# 328              NaN         NaN   42.3594  -71.0587    Employee Generated
# 337              NaN         NaN   42.3202  -71.0612       City Worker App
# ...              ...         ...       ...       ...                   ...
# 973721           NaN         NaN   42.2872  -71.1066      Constituent Call
# 973722           NaN         NaN   42.3594  -71.0587  Citizens Connect App
# 973723           NaN         NaN   42.3594  -71.0587  Citizens Connect App
# 973729           NaN         NaN   42.3511  -71.0620  Citizens Connect App
# 973733           NaN         NaN   42.3523  -71.0618  Citizens Connect App
# 973734           NaN         NaN   42.3430  -71.1545  Citizens Connect App
# 973750           NaN         NaN   42.3200  -71.1084  Citizens Connect App
# 973764           NaN         NaN   42.3632  -71.0688  Citizens Connect App
# 973766           NaN         NaN   42.3526  -71.0647  Citizens Connect App
# 973777           NaN         NaN   42.3594  -71.0587      Constituent Call
# 973789           NaN         NaN   42.3594  -71.0587  Citizens Connect App
# 973793           NaN         NaN   42.3407  -71.0767  Citizens Connect App
# 973795           NaN         NaN   42.3415  -71.0810  Citizens Connect App
# 973808           NaN         NaN   42.3594  -71.0587      Constituent Call
# 973815           NaN         NaN   42.3578  -71.0609  Citizens Connect App
# 973821           NaN         NaN   42.3594  -71.0587      Constituent Call
# 973831           NaN         NaN   42.3594  -71.0587  Citizens Connect App
# 973843           NaN         NaN   42.3573  -71.0538  Citizens Connect App
# 973887           NaN         NaN   42.3608  -71.0638  Citizens Connect App
# 973897           NaN         NaN   42.2506  -71.1257       City Worker App
# 973902           NaN         NaN   42.3313  -71.0637      Constituent Call
# 973907           NaN         NaN   42.3109  -71.1305      Constituent Call
# 973928           NaN         NaN   42.3594  -71.0587  Citizens Connect App
# 973936           NaN         NaN   42.3359  -71.1007  Citizens Connect App
# 973947           NaN         NaN   42.3533  -71.1624       City Worker App
# 973967           NaN         NaN   42.2662  -71.1607  Citizens Connect App
# 973974           NaN         NaN   42.3594  -71.0587  Citizens Connect App
# 973979           NaN         NaN   42.3088  -71.0818  Citizens Connect App
# 973982           NaN         NaN   42.3519  -71.0831  Citizens Connect App
# 973989           NaN         NaN   42.3824  -71.0197      Constituent Call
#
#        Geocoded_Location
# 51                   NaN
# 67                   NaN
# 89                   NaN
# 92                   NaN
# 94                   NaN
# 107                  NaN
# 124                  NaN
# 137                  NaN
# 147                  NaN
# 151                  NaN
# 154                  NaN
# 174                  NaN
# 179                  NaN
# 203                  NaN
# 207                  NaN
# 211                  NaN
# 252                  NaN
# 253                  NaN
# 257                  NaN
# 266                  NaN
# 276                  NaN
# 285                  NaN
# 287                  NaN
# 289                  NaN
# 306                  NaN
# 312                  NaN
# 316                  NaN
# 318                  NaN
# 328                  NaN
# 337                  NaN
# ...                  ...
# 973721               NaN
# 973722               NaN
# 973723               NaN
# 973729               NaN
# 973733               NaN
# 973734               NaN
# 973750               NaN
# 973764               NaN
# 973766               NaN
# 973777               NaN
# 973789               NaN
# 973793               NaN
# 973795               NaN
# 973808               NaN
# 973815               NaN
# 973821               NaN
# 973831               NaN
# 973843               NaN
# 973887               NaN
# 973897               NaN
# 973902               NaN
# 973907               NaN
# 973928               NaN
# 973936               NaN
# 973947               NaN
# 973967               NaN
# 973974               NaN
# 973979               NaN
# 973982               NaN
# 973989               NaN
#
# [77677 rows x 33 columns]

# %%
pothole_profile = pdp.ProfileReport(potdf[important_cols])
# Out:
# /opt/conda/lib/python3.5/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}
# /opt/conda/lib/python3.5/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}
# /opt/conda/lib/python3.5/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}

# %%
pothole_profile.to_file(outputfile="pothole_profile.html")

pothole_profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>24 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>77677 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>21.7% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>14.2 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>192.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>4 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>CASE_TITLE</code> has a high cardinality: 116 distinct values  <span class="label label-warning">Warning</span></l><li><code>CLOSURE_REASON</code> has 38442 / 49.5% missing values <span class="label label-default">Missing</span></l><li><code>ClosedPhoto</code> has 68156 / 87.7% missing values <span class="label label-default">Missing</span></l><li><code>ClosedPhoto</code> has a high cardinality: 9522 distinct values  <span class="label label-warning">Warning</span></l><li><code>Geocoded_Location</code> has 77677 / 100.0% missing values <span class="label label-default">Missing</span></l><li><code>Geocoded_Location</code> has constant value  <span class="label label-primary">Rejected</span></l><li><code>Property_Type</code> has 77677 / 100.0% missing values <span class="label label-default">Missing</span></l><li><code>Property_Type</code> has constant value  <span class="label label-primary">Rejected</span></l><li><code>QUEUE</code> has a high cardinality: 97 distinct values  <span class="label label-warning">Warning</span></l><li><code>SubmittedPhoto</code> has 61891 / 79.7% missing values <span class="label label-default">Missing</span></l><li><code>SubmittedPhoto</code> has a high cardinality: 15781 distinct values  <span class="label label-warning">Warning</span></l><li><code>fire_district</code> has 789 / 1.0% missing values <span class="label label-default">Missing</span></l><li><code>land_usage</code> has 77677 / 100.0% missing values <span class="label label-default">Missing</span></l><li><

# %% [markdown]
# # Potholes by Neigborhood

# %%
import collections
dd = collections.Counter(potdf['neighborhood'].dropna())
dd
# plt.bar(dd.values(), dd.keys())
l = range(len(dd.keys()))
plt.bar(l, dd.values(), align='center')
plt.xticks(l, dd.keys(), rotation='vertical')
plt.show()

# %% [markdown]
# # Potholes by City Council District

# %%
import collections
dd = collections.Counter(potdf['city_council_district'].dropna())
dd
# plt.bar(dd.values(), dd.keys())
l = range(len(dd.keys()))
plt.bar(l, dd.values(), align='center')
plt.xticks(l, dd.keys(), rotation='vertical')
plt.show()

# %% [markdown]
# # Age of Potholes
#
# 'OPEN_DT', 'TARGET_DT', 'CLOSED_DT'
#
# `age =  DateClosed('CLOSED_DT') - DateCreated('OPEN_DT')`
#
# `expected_age = TargetDate('TARGET_DT') - DateCreate('OPEN_DT') `
#
# `performance = expected_age - age`

# %%
potdf['age'] =  pd.to_datetime(potdf['CLOSED_DT']) - pd.to_datetime(potdf['OPEN_DT'])
potdf['expected_age'] =  pd.to_datetime(potdf['TARGET_DT']) - pd.to_datetime(potdf['OPEN_DT'])
potdf['performance'] = potdf['expected_age'] - potdf['age']
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
closedpotdf = potdf['age'].dropna()
potdf['age_in_days'] = closedpotdf.apply(lambda x: x.days if isinstance(good, pd.Timedelta) else 0)
potdf['age_in_days'].dropna()
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# 51         0.0
# 67         0.0
# 89         0.0
# 92         0.0
# 94         0.0
# 107        0.0
# 124        0.0
# 137        6.0
# 147        1.0
# 151        1.0
# 154        0.0
# 174        0.0
# 179        0.0
# 203        0.0
# 207        0.0
# 211        1.0
# 252        0.0
# 253        0.0
# 257       13.0
# 266        0.0
# 276        0.0
# 285        0.0
# 287        0.0
# 289        0.0
# 306        0.0
# 312        0.0
# 316        0.0
# 318        0.0
# 328        0.0
# 337        0.0
#           ...
# 973461     1.0
# 973513     1.0
# 973526     0.0
# 973554     2.0
# 973580     0.0
# 973643     2.0
# 973657     0.0
# 973696     1.0
# 973700     0.0
# 973713     2.0
# 973720     4.0
# 973721     0.0
# 973723     5.0
# 973733     1.0
# 973734     0.0
# 973750     0.0
# 973764     3.0
# 973777     1.0
# 973793    12.0
# 973815     1.0
# 973831     0.0
# 973843     0.0
# 973887     3.0
# 973897     0.0
# 973902     3.0
# 973907     0.0
# 973947     0.0
# 973967     0.0
# 973979     0.0
# 973982     8.0
# Name: age_in_days, dtype: float64

# %%
import collections

# df = df[df.line_race != 0]

dd = collections.Counter(potdf['neighborhood'].dropna())
age_dd = collections.Counter(potdf['age_in_days'].dropna())
age_dd
# # plt.bar(dd.values(), dd.keys())
# l = range(len(60)
plt.hist(x=potdf['age_in_days'], data=potdf['neighborhood'])
# # plt.xticks(l, age_dd.keys(), rotation='vertical')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-240-fb8438ef3b4d> in <module>()
#       8 # # plt.bar(dd.values(), dd.keys())
#       9 # l = range(len(60)
# ---> 10 plt.hist(x=potdf['age_in_days'], data=potdf['neighborhood'])
#      11 # # plt.xticks(l, age_dd.keys(), rotation='vertical')
#      12 # plt.show()
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/pyplot.py in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    2956                       histtype=histtype, align=align, orientation=orientation,
#    2957                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2958                       stacked=stacked, data=data, **kwargs)
#    2959     finally:
#    2960         ax.hold(washold)
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6008             # this will automatically overwrite bins,
#    6009             # so that each histogram uses the same bins
# -> 6010             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6011             m = m.astype(float)  # causes problems later if it's an int
#    6012             if mlast is None:
#
# /opt/conda/lib/python3.5/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     174         if (mn > mx):
#     175             raise AttributeError(
# --> 176                 'max must be larger than min in range parameter.')
#     177
#     178     # Histogram is an integer or a float array depending on the weights.
#
# AttributeError: max must be larger than min in range parameter.

# %%
potdf['age_in_days'].describe()
# Out:
# count    75510.000000
# mean         2.138803
# std         20.836784
# min         -1.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       1378.000000
# Name: age_in_days, dtype: float64

# %%
# print(potdf.age)
bad = potdf.age[973808]
# print('fuck') if bad.second.is_integer() else print('nope')

    
# fff = bad.second
# bad == pd.Timedelta('NaT')
# pd.notnull(bad)
bad.day
isinstance(bad, pd.Timedelta)
# Out:
# False

# %%
good = potdf.age[51]
isinstance(good, pd.Timedelta)
# good.day
# Out:
# True

# %%
p = potdf['age_in_days'].plot.hist()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-248-f1f8bf2ba856> in <module>()
#       1 p = potdf['age_in_days'].plot.hist()
# ----> 2 p.draw()
#
# TypeError: draw_wrapper() missing 1 required positional argument: 'renderer'

# %%
plt.show()

# %%
from collections import defaultdict
age
